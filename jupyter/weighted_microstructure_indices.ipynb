# %%
import numpy as np
import nibabel as nib

import dipy.tracking.utils
import dipy.tracking.streamline

import pandas as pd
import os

import nipype.interfaces.dipy
import nipype.interfaces.mrtrix3

# %%
# %run load_connectivity_data.ipynb

# %%
data_dir = "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri"

def get_patient_dir(patient_id):
    return os.path.join(
        data_dir, "patient%02d/bids/sub-patient%02d/ses-presurgical" % (patient_id, patient_id)
    )

def get_tck_streamlines_dir(patient_id):
    return os.path.join(
        get_patient_dir(patient_id), "connectivity/tck_streamlines"
    )

def get_tck_streamlines_file(patient_id, stimulation_site, recording_electrode):
    return os.path.join(
        get_tck_streamlines_dir(patient_id),
        "%s_%s_diam10_in00.tck" % (stimulation_site, recording_electrode)
    )

def get_trk_streamlines_dir(patient_id):
    return os.path.join(
        get_patient_dir(patient_id), "connectivity/streamlines"
    )

def get_trk_streamlines_file(patient_id, stimulation_site, recording_electrode):
    return os.path.join(
        get_trk_streamlines_dir(patient_id),
        "%s_%s_diam10_in00.trk" % (stimulation_site, recording_electrode)
    )

def get_weights_file(patient_id, stimulation_site, recording_electrode):
    return os.path.join(
        get_tck_streamlines_dir(patient_id),
        "%s_%s_diam10_in00_weight.txt" % (stimulation_site, recording_electrode)
    )

def get_tdi_file(patient_id, stimulation_site, recording_electrode):
    return os.path.join(
        get_tck_streamlines_dir(patient_id), 
        "%s_%s_diam10_in00_weighted_tckmap.nii.gz" % (stimulation_site, recording_electrode)
    )

def get_template_file(patient_id):
    return os.path.join(
        get_patient_dir(patient_id), 
        "tractography/sub-patient%02d_ses-presurgical_dti_FA.nii.gz" % patient_id
    )

# %%
for patient_id in [4]:

    for data_row in data_pd[patient_id].iterrows():

        try:
            tck2tdi = nipype.interfaces.mrtrix3.ComputeTDI(
                in_file=get_tck_streamlines_file(patient_id, data_row[1]['stimulation_site'], data_row[1]['recording_electrode']),
                out_file=get_tdi_file(patient_id, data_row[1]['stimulation_site'], data_row[1]['recording_electrode']),
                reference=get_template_file(patient_id),
                tck_weights=get_weights_file(patient_id, data_row[1]['stimulation_site'], data_row[1]['recording_electrode']),
            )
            tck2tdi.run() 
        except:
            print("Couldn't process file: %s", get_tck_streamlines_file(patient_id, data_row[1]['stimulation_site'], data_row[1]['recording_electrode']))
# Out:
# 190813-14:52:49,744 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:52:50,145 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e01_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:52:52,100 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:52:52,374 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e02_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:52:53,230 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:52:53,489 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e03_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:52:54,633 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:52:54,895 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e04_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:52:55,483 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:52:55,748 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e05_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:52:56,301 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:52:56,555 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e06_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:52:56,882 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:52:57,116 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e07_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:52:57,430 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:52:57,652 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e08_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:54:11,572 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:54:12,608 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e09_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:55:10,211 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:55:10,701 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e10_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:55:38,157 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:55:38,738 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e11_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:55:53,21 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:55:53,424 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e12_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:56:02,169 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:56:02,581 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e13_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:56:05,637 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:56:06,158 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s00_e14_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:56:07,861 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:56:08,183 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s01_e01_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:56:09,922 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:56:10,238 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s01_e02_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:56:11,115 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-14:56:11,429 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s01_e03_diam10_in00_weighted_tckmap.nii.gz"
# 190813-14:56
nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e03_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:03,37 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:03,628 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e04_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:19,578 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:20,45 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e05_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:33,345 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:33,814 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e06_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:37,281 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:37,663 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e07_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:43,653 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:44,207 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e08_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:47,61 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:47,383 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e09_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:49,480 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:49,884 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e10_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:52,302 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:52,630 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e11_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:31:57,40 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:31:57,376 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e12_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:32:10,237 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:32:10,792 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e13_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:32:23,130 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:32:23,542 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s08_e14_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:32:36,611 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:32:37,53 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e01_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:33:05,66 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:33:05,594 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e02_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:33:32,816 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:33:33,330 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e03_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:34:44,87 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:34:44,679 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e04_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:34:48,349 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:34:48,703 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e05_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:34:51,78 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:34:51,455 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e06_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:34:53,459 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:34:53,775 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e07_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:34:56,514 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:34:56,845 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e08_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:34:59,958 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:35:00,274 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e09_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:35:04,45 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:35:04,387 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e10_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:35:07,549 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:35:07,922 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e11_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:35:14,10 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:35:14,375 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e12_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:35:36,212 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:35:36,581 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e13_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:35:58,19 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:35:58,583 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s09_e14_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:36:06,648 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:36:07,43 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e01_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:36:24,767 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:36:25,621 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e02_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:36:40,301 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:36:40,711 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e03_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:36:48,192 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:36:48,720 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e04_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:40:36,458 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:40:37,137 nipype.interface INFO:
# ...
# 190813-15:43:23,366 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:43:23,732 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e09_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:43:24,174 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:43:24,462 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e10_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:43:24,869 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:43:25,283 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e11_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:43:26,166 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:43:26,464 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e12_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:43:28,480 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:43:28,883 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e13_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:43:30,757 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:43:31,112 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s10_e14_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:43:37,43 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:43:37,460 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e01_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:43:49,52 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:43:49,685 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e02_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:44:09,93 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:44:09,535 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e03_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:44:17,456 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:44:17,846 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e04_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:45:15,933 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:45:16,442 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e05_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:49:03,74 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:49:03,738 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e06_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:49:51,305 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:49:51,879 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e07_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:50:23,794 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:50:24,286 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e08_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:50:24,947 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:50:25,225 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e09_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:50:26,101 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:50:26,407 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e10_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:50:26,939 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:50:27,238 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e11_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:50:28,2 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:50:28,316 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e12_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:50:29,58 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:50:29,375 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e13_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:50:30,378 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:50:30,690 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s11_e14_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:50:47,58 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:50:47,506 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e01_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:51:26,630 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:51:27,113 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e02_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:52:47,529 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:52:48,157 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e03_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:53:12,16 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:53:12,436 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e04_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:54:02,779 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:54:03,264 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e05_diam10_in00_weighted_tckmap.nii.gz"
# 190813-15:57:06,183 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-15:57:06,746 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e06_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:00:15,11 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:00:15,672 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e07_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:03:16,595 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:03:17,275 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e08_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:03:17,909 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:03:18,343 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e09_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:03:18,932 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:03:19,278 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e10_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:03:19,902 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:03:20,166 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e11_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:03:20,787 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:03:21,63 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e12_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:03:22,171 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:03:22,464 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e13_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:03:24,6 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:03:24,331 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s12_e14_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:03:41,914 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:03:42,295 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e01_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:04:18,659 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:04:19,83 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e02_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:05:19,477 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:05:20,266 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e03_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:08:16,987 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:08:17,826 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e04_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:08:36,99 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:08:36,532 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e05_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:09:08,482 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:09:08,981 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e06_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:09:49,176 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:09:49,830 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e07_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:11:27,543 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:11:28,375 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e08_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:11:29,260 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:11:29,588 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e09_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:11:30,780 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:11:31,55 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e10_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:11:32,626 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:11:32,947 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e11_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:11:34,123 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:11:34,396 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e12_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:11:37,656 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:11:37,974 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e13_diam10_in00_weighted_tckmap.nii.gz"
# 190813-16:11:42,717 nipype.interface INFO:
# tckmap: [100%] mapping tracks to image
# 190813-16:11:43,94 nipype.interface INFO:
# tckmap: [100%] compressing image "/user/pfilipia/home/inria/chu_nice_inria/patients_dmri/patient04/bids/sub-patient04/ses-presurgical/connectivity/tck_streamlines/s13_e14_diam10_in00_weighted_tckmap.nii.gz"
